# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
datos = pd.read_csv("proyecto_datos.csv")

# %%
datos
# Out:
#           Marca temporal                         Nombre     Género Altura   \
# 0    11/09/2022 15:52:19                   Andrea Pérez   Femenino    1.60
# 1    11/09/2022 15:56:19                         Laura    Femenino    1.70
# 2    11/09/2022 15:59:12               Suyapa Rodríguez   Femenino    1.62
# 3    11/09/2022 16:01:52                 Carlos Cordero  Masculino    1.80
# 4    11/09/2022 16:01:55                Sandra Peralta    Femenino    1.56
# ..                   ...                            ...        ...     ...
# 148  14/09/2022 19:09:00    Pablo Andres Duarte Cabrera  Masculino    1:75
# 149  14/09/2022 19:09:16                       Dany Aju  Masculino    1.58
# 150  14/09/2022 19:09:28                         Andrés  Masculino    1.60
# 151  14/09/2022 19:10:50                Henry Amezquita  Masculino    1.69
# 152  18/09/2022 21:27:49  Camila Mayté Sinclair Vargas    Femenino    1.65
#
#      Peso                                    Actividad_fisica  Edad
# ...

# %%
type(datos)
# Out:
# pandas.core.frame.DataFrame

# %%
datos.Género
# Out:
# 0       Femenino
# 1       Femenino
# 2       Femenino
# 3      Masculino
# 4       Femenino
#          ...
# 148    Masculino
# 149    Masculino
# 150    Masculino
# 151    Masculino
# 152     Femenino
# Name: Género, Length: 153, dtype: object

# %%
femenino = datos[datos.Género == "Femenino"]

# %%
femenino
# Out:
#           Marca temporal                                Nombre    Género  \
# 0    11/09/2022 15:52:19                          Andrea Pérez  Femenino
# 1    11/09/2022 15:56:19                                Laura   Femenino
# 2    11/09/2022 15:59:12                      Suyapa Rodríguez  Femenino
# 4    11/09/2022 16:01:55                       Sandra Peralta   Femenino
# 13   11/09/2022 16:19:49         Aracely Mirtala Molina Molina  Femenino
# 14   11/09/2022 16:20:06                         Amy Aplicano   Femenino
# 23   11/09/2022 16:37:26                         Nicole Rivera  Femenino
# 26   11/09/2022 16:46:35                          Ana Peralta   Femenino
# 28   11/09/2022 16:48:57        Katy waleska Molina Rodriguez   Femenino
# 46   11/09/2022 17:33:50                Zulema Mendoza Torres   Femenino
# 49   11/09/2022 18:04:04        Sara Stephannie Sandoval Morán  Femenino
# 54   11/09/2022 18:57:48                              Marilis   Femenino
# ...

# %%
masculino = datos[datos.Género == "Masculino"]

# %%
masculino
# Out:
#           Marca temporal                            Nombre     Género Altura   \
# 3    11/09/2022 16:01:52                    Carlos Cordero  Masculino    1.80
# 5    11/09/2022 16:03:13                   Moisés Estribí   Masculino    1.67
# 6    11/09/2022 16:04:44    Marvin Omar colindres Andrade   Masculino    1.78
# 7    11/09/2022 16:05:35  Christofher Omar Aguilar Fonseca  Masculino    1.70
# 8    11/09/2022 16:06:14                  Oscar Girón Paiz  Masculino    1.70
# ..                   ...                               ...        ...     ...
# 147  14/09/2022 19:07:57                     Jorge Aguirre  Masculino    1.80
# 148  14/09/2022 19:09:00       Pablo Andres Duarte Cabrera  Masculino    1:75
# 149  14/09/2022 19:09:16                          Dany Aju  Masculino    1.58
# 150  14/09/2022 19:09:28                            Andrés  Masculino    1.60
# 151  14/09/2022 19:10:50                   Henry Amezquita  Masculino    1.69
#
# ...

# %%
plt.plot(femenino.Edad)
plt.plot(masculino.Edad)
plt.legend(["Femenino", "Masculino"])
plt.xlabel("Personas")
plt.ylabel("Edad")
plt.show()
